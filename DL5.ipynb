# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).
#
# ## Data
# CIFAR-10  is an established computer-vision dataset used for object recognition. It is a subset of the 80 million tiny images dataset and consists of 60,000 32x32 color images containing one of 10 object classes, with 6000 images per class. It was collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton.

# %% [markdown]
# Let's get the data by running the following function

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()
# Out:
# CIFAR-10 Dataset: 171MB [02:54, 977kB/s]

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %% [markdown]
# ## The following are some helper functions students can use in their code

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer


def _load_label_names():
    """
    Load the label names from file
    """
    return ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']


def load_cfar10_batch(cifar10_dataset_folder_path, batch_id):
    """
    Load a batch of the dataset
    """
    with open(cifar10_dataset_folder_path + '/data_batch_' + str(batch_id), mode='rb') as file:
        batch = pickle.load(file, encoding='latin1')

    features = batch['data'].reshape((len(batch['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    labels = batch['labels']

    return features, labels


def display_stats(cifar10_dataset_folder_path, batch_id, sample_id):
    """
    Display Stats of the the dataset
    """
    batch_ids = list(range(1, 6))

    if batch_id not in batch_ids:
        print('Batch Id out of Range. Possible Batch Ids: {}'.format(batch_ids))
        return None

    features, labels = load_cfar10_batch(cifar10_dataset_folder_path, batch_id)

    if not (0 <= sample_id < len(features)):
        print('{} samples in batch {}.  {} is out of range.'.format(len(features), batch_id, sample_id))
        return None

    print('\nStats of batch {}:'.format(batch_id))
    print('Samples: {}'.format(len(features)))
    print('Label Counts: {}'.format(dict(zip(*np.unique(labels, return_counts=True)))))
    print('First 20 Labels: {}'.format(labels[:20]))

    sample_image = features[sample_id]
    sample_label = labels[sample_id]
    label_names = _load_label_names()

    print('\nExample of Image {}:'.format(sample_id))
    print('Image - Min Value: {} Max Value: {}'.format(sample_image.min(), sample_image.max()))
    print('Image - Shape: {}'.format(sample_image.shape))
    print('Label - Label Id: {} Name: {}'.format(sample_label, label_names[sample_label]))
    plt.axis('off')
    plt.imshow(sample_image)


def _preprocess_and_save(normalize, one_hot_encode, features, labels, filename):
    """
    Preprocess data and save it to file
    """
    features = normalize(features)
    labels = one_hot_encode(labels)

    pickle.dump((features, labels), open(filename, 'wb'))


def preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode):
    """
    Preprocess Training and Validation Data
    """
    n_batches = 5
    valid_features = []
    valid_labels = []

    for batch_i in range(1, n_batches + 1):
        features, labels = load_cfar10_batch(cifar10_dataset_folder_path, batch_i)
        validation_count = int(len(features) * 0.1)

        # Prprocess and save a batch of training data
        _preprocess_and_save(
            normalize,
            one_hot_encode,
            features[:-validation_count],
            labels[:-validation_count],
            'preprocess_batch_' + str(batch_i) + '.p')

        # Use a portion of training batch for validation
        valid_features.extend(features[-validation_count:])
        valid_labels.extend(labels[-validation_count:])

    # Preprocess and Save all validation data
    _preprocess_and_save(
        normalize,
        one_hot_encode,
        np.array(valid_features),
        np.array(valid_labels),
        'preprocess_validation.p')

    with open(cifar10_dataset_folder_path + '/test_batch', mode='rb') as file:
        batch = pickle.load(file, encoding='latin1')

    # load the training data
    test_features = batch['data'].reshape((len(batch['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    test_labels = batch['labels']

    # Preprocess and Save all training data
    _preprocess_and_save(
        normalize,
        one_hot_encode,
        np.array(test_features),
        np.array(test_labels),
        'preprocess_training.p')


def batch_features_labels(features, labels, batch_size):
    """
    Split features and labels into batches
    """
    for start in range(0, len(features), batch_size):
        end = min(start + batch_size, len(features))
        yield features[start:end], labels[start:end]


def load_preprocess_training_batch(batch_id, batch_size):
    """
    Load the Preprocessed Training data and return them in batches of <batch_size> or less
    """
    filename = 'preprocess_batch_' + str(batch_id) + '.p'
    features, labels = pickle.load(open(filename, mode='rb'))

    # Return the training data in batches of size <batch_size> or less
    return batch_features_labels(features, labels, batch_size)


def display_image_predictions(features, labels, predictions):
    n_classes = 10
    label_names = _load_label_names()
    label_binarizer = LabelBinarizer()
    label_binarizer.fit(range(n_classes))
    label_ids = label_binarizer.inverse_transform(np.array(labels))

    fig, axies = plt.subplots(nrows=4, ncols=2)
    fig.tight_layout()
    fig.suptitle('Softmax Predictions', fontsize=20, y=1.1)

    n_predictions = 3
    margin = 0.05
    ind = np.arange(n_predictions)
    width = (1. - 2. * margin) / n_predictions

    for image_i, (feature, label_id, pred_indicies, pred_values) in enumerate(zip(features, label_ids, predictions.indices, predictions.values)):
        pred_names = [label_names[pred_i] for pred_i in pred_indicies]
        correct_name = label_names[label_id]

        axies[image_i][0].imshow(feature*255)
        axies[image_i][0].set_title(correct_name)
        axies[image_i][0].set_axis_off()

        axies[image_i][1].barh(ind + margin, pred_values[::-1], width)
        axies[image_i][1].set_yticks(ind + margin)
        axies[image_i][1].set_yticklabels(pred_names[::-1])
        axies[image_i][1].set_xticks([0, 0.5, 1.0])

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np

# Explore the dataset
batch_id = 3
sample_id = 5
display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 3:
# Samples: 10000
# Label Counts: {0: 994, 1: 1042, 2: 965, 3: 997, 4: 990, 5: 1029, 6: 978, 7: 1015, 8: 961, 9: 1029}
# First 20 Labels: [8, 5, 0, 6, 9, 2, 8, 3, 6, 2, 7, 4, 6, 9, 0, 0, 7, 3, 7, 2]
#
# Example of Image 5:
# Image - Min Value: 9 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 2 Name: bird

# %% [markdown]
# # Solution

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
import numpy as np
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
     # Implement Function
    min = np.min(x)
    max = np.max(x)
    output = (x-min)/(max-min)
   
    return output

# %% [markdown]
# ### One-hot encode
# We'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(range(10))
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    
    return np.eye(10)[x]

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %%
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %%
import tensorflow as tf

# %% [markdown]
# ## Build the network
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, shape = (None, image_shape[0], image_shape[1], image_shape[2]), name = 'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape = (None, n_classes), name = 'y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    
    return tf.placeholder(tf.float32, shape = (None) , name="keep_prob")


tf.reset_default_graph()

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    shape_of_x_tensor = x_tensor.get_shape().as_list()
    F_W = tf.Variable(tf.truncated_normal([conv_ksize[0] ,conv_ksize[1] ,shape_of_x_tensor[-1] ,conv_num_outputs] 
                                          ,dtype=tf.float32, stddev=0.2))
    F_b = tf.Variable(tf.zeros([conv_num_outputs]  ,dtype=tf.float32))
    strides_conv = [1, conv_strides[0], conv_strides[1], 1]
    padding = 'SAME'
    output = tf.nn.conv2d(x_tensor, F_W, strides_conv, padding)
    output = tf.nn.bias_add(output, F_b)
    output = tf.nn.relu(output)
    ksize_maxpool = [1, pool_ksize[0], pool_ksize[1], 1]
    strides_maxpool = [1, pool_strides[0], pool_strides[1], 1]
    output = tf.nn.max_pool(output, ksize_maxpool, strides_maxpool, padding)
    
    return output

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # Implement Function
    shape = x_tensor.get_shape().as_list() # [None, 10, 30, 6]
    dimension = shape[1]*shape[2]*shape[3] # 18000
    return tf.reshape(x_tensor, [-1, (dimension)])

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Implement Function
    
    shape = x_tensor.get_shape().as_list()
    weights = tf.Variable(tf.truncated_normal([shape[1], num_outputs], dtype=tf.float32, stddev=0.05))
    bias = tf.Variable(tf.zeros(num_outputs),dtype=tf.float32 )
    fc = tf.add(tf.matmul(x_tensor, weights), bias)
    return tf.nn.relu(fc)

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    
    shape = x_tensor.get_shape().as_list()
    weights= tf.Variable(tf.truncated_normal([shape[1], num_outputs] ,dtype=tf.float32, stddev=0.05))
    biases = tf.Variable(tf.zeros([num_outputs])) #  ,dtype=tf.float32))
    out = tf.add(tf.matmul(x_tensor, weights), biases)
    return out

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """

    out = conv2d_maxpool(x, conv_num_outputs = 16, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))
    out = conv2d_maxpool(out, conv_num_outputs = 32, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))
    out = conv2d_maxpool(out, conv_num_outputs = 64, conv_ksize = (3,3), conv_strides = (1,1), pool_ksize=(2,2), pool_strides=(2,2))

    # Function Definition from Above:
    flat_x  = flatten(out)
    
   
    # call fully_conn function with 64,32,16 num_outputs, along with dropout after each full_conn, and final output with 10 num_outputs
    fc = fully_conn(flat_x, 64)
    fc = tf.nn.dropout(fc , keep_prob) 
    fc = fully_conn(fc, 32)
    fc = tf.nn.dropout(fc , keep_prob)     
    fc = fully_conn(fc, 16)
    fc = tf.nn.dropout(fc, keep_prob)

    outp = tf.nn.dropout(output(fc, 10), keep_prob)
#    outp = output(out,num_outputs=10)
    return outp


##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')
# Out:
# WARNING:tensorflow:From <ipython-input-15-71ac2e222d3d>:50: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch,keep_prob:keep_probability})

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    valid_acc = sess.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.})
    train_acc = sess.run(accuracy, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    train_cost = sess.run(cost, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    print('Cost {::>8.5f}, Accuracy on Training {:.4f} -'
                  'Validation Accuracy: {:.4f}'.format(
                train_cost,
                train_acc,
                valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
epochs = 50
batch_size = 128
keep_probability = 0.75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost :2.21889, Accuracy on Training 0.1750 -Validation Accuracy: 0.1878
# Epoch  2, CIFAR-10 Batch 1:  Cost :2.12751, Accuracy on Training 0.2500 -Validation Accuracy: 0.2610
# Epoch  3, CIFAR-10 Batch 1:  Cost :2.06946, Accuracy on Training 0.3000 -Validation Accuracy: 0.3016
# Epoch  4, CIFAR-10 Batch 1:  Cost :2.03176, Accuracy on Training 0.3000 -Validation Accuracy: 0.3320
# Epoch  5, CIFAR-10 Batch 1:  Cost :1.98568, Accuracy on Training 0.3250 -Validation Accuracy: 0.3278
# Epoch  6, CIFAR-10 Batch 1:  Cost :1.92126, Accuracy on Training 0.3000 -Validation Accuracy: 0.3504
# Epoch  7, CIFAR-10 Batch 1:  Cost :1.88230, Accuracy on Training 0.3750 -Validation Accuracy: 0.3904
# Epoch  8, CIFAR-10 Batch 1:  Cost :1.82355, Accuracy on Training 0.3500 -Validation Accuracy: 0.3780
# Epoch  9, CIFAR-10 Batch 1:  Cost :1.79430, Accuracy on Training 0.3500 -Validation Accuracy: 0.3688
# Epoch 10, CIFAR-10 Batch 1:  Cost :1.70191, Accuracy on Training 0.4250 -Validation Accuracy: 0.4118
# Epoch 11, CIFAR-10 Batch 1:  Cost :1.60851, Accuracy on Training 0.4000 -Validation Accuracy: 0.4186
# Epoch 12, CIFAR-10 Batch 1:  Cost :1.57495, Accuracy on Training 0.5250 -Validation Accuracy: 0.4166
# Epoch 13, CIFAR-10 Batch 1:  Cost :1.57144, Accuracy on Training 0.5000 -Validation Accuracy: 0.4200
# Epoch 14, CIFAR-10 Batch 1:  Cost :1.47650, Accuracy on Training 0.5000 -Validation Accuracy: 0.4304
# Epoch 15, CIFAR-10 Batch 1:  Cost :1.42953, Accuracy on Training 0.5500 -Validation Accuracy: 0.4436
# Epoch 16, CIFAR-10 Batch 1:  Cost :1.34137, Accuracy on Training 0.5500 -Validation Accuracy: 0.4546
# Epoch 17, CIFAR-10 Batch 1:  Cost :1.27341, Accuracy on Training 0.5750 -Validation Accuracy: 0.4632
# Epoch 18, CIFAR-10 Batch 1:  Cost :1.24421, Accuracy on Training 0.5250 -Validation Accuracy: 0.4542
# Epoch 19, CIFAR-10 Batch 1:  Cost :1.18236, Accuracy on Training 0.6500 -Validation Accuracy: 0.4836
# Epoch 20, CIFAR-10 Batch 1:  Cost :1.15338, Accuracy on Training 0.6250 -Validation Accuracy: 0.4876
# Epoch 21, CIFAR-10 Batch 1:  Cost :1.10421, Accuracy on Training 0.6500 -Validation Accuracy: 0.4926
# Epoch 22, CIFAR-10 Batch 1:  Cost :1.04570, Accuracy on Training 0.6000 -Validation Accuracy: 0.4908
# Epoch 23, CIFAR-10 Batch 1:  Cost :1.04990, Accuracy on Training 0.6000 -Validation Accuracy: 0.5008
# Epoch 24, CIFAR-10 Batch 1:  Cost :1.02351, Accuracy on Training 0.6250 -Validation Accuracy: 0.5096
# Epoch 25, CIFAR-10 Batch 1:  Cost :0.95121, Accuracy on Training 0.7000 -Validation Accuracy: 0.5088
# Epoch 26, CIFAR-10 Batch 1:  Cost :0.94446, Accuracy on Training 0.6750 -Validation Accuracy: 0.4984
# Epoch 27, CIFAR-10 Batch 1:  Cost :0.93098, Accuracy on Training 0.7000 -Validation Accuracy: 0.5040
# Epoch 28, CIFAR-10 Batch 1:  Cost :0.86511, Accuracy on Training 0.6750 -Validation Accuracy: 0.4860
# Epoch 29, CIFAR-10 Batch 1:  Cost :0.84705, Accuracy on Training 0.7000 -Validation Accuracy: 0.4874
# Epoch 30, CIFAR-10 Batch 1:  Cost :0.80104, Accuracy on Training 0.6500 -Validation Accuracy: 0.4920
# Epoch 31, CIFAR-10 Batch 1:  Cost :0.81481, Accuracy on Training 0.7250 -Validation Accuracy: 0.4868
# Epoch 32, CIFAR-10 Batch 1:  Cost :0.79159, Accuracy on Training 0.8000 -Validation Accuracy: 0.4986
# Epoch 33, CIFAR-10 Batch 1:  Cost :0.78318, Accuracy on Training 0.6750 -Validation Accuracy: 0.5110
# Epoch 34, CIFAR-10 Batch 1:  Cost :0.75424, Accuracy on Training 0.7250 -Validation Accuracy: 0.5222
# Epoch 35, CIFAR-10 Batch 1:  Cost :0.79558, Accuracy on Training 0.7000 -Validation Accuracy: 0.5082
# Epoch 36, CIFAR-10 Batch 1:  Cost :0.74140, Accuracy on Training 0.7750 -Validation Accuracy: 0.5166
# Epoch 37, CIFAR-10 Batch 1:  Cost :0.74210, Accuracy on Training 0.7250 -Validation Accuracy: 0.5190
# Epoch 38, CIFAR-10 Batch 1:  Cost :0.70180, Accuracy on Training 0.8000 -Validation Accuracy: 0.5196
# Epoch 39, CIFAR-10 Batch 1:  Cost :0.69232, Accuracy on Training 0.7500 -Validation Accuracy: 0.5254
# Epoch 40, CIFAR-10 Batch 1:  Cost :0.75715, Accuracy on Training 0.7750 -Validation Accuracy: 0.5150
# Epoch 41, CIFAR-10 Batch 1:  Cost :0.70860, Accuracy on Training 0.7500 -Validation Accuracy: 0.5328
# Epoch 42, CIFAR-10 Batch 1:  Cost :0.69134, Accuracy on Training 0.7250 -Validation Accuracy: 0.5302
# Epoch 43, CIFAR-10 Batch 1:  Cost :0.67057, Accuracy on Training 0.7500 -Validation Accuracy: 0.5212
# Epoch 44, CIFAR-10 Batch 1:  Cost :0.65732, Accuracy on Training 0.7500 -Validation Accuracy: 0.5270
# Epoch 45, CIFAR-10 Batch 1:  Cost :0.61558, Accuracy on Training 0.8000 -Validation Accuracy: 0.5220
# Epoch 46, CIFAR-10 Batch 1:  Cost :0.59624, Accuracy on Training 0.8500 -Validation Accuracy: 0.5284
# Epoch 47, CIFAR-10 Batch 1:  Cost :0.61704, Accuracy on Training 0.8250 -Validation Accuracy: 0.5380
# Epoch 48, CIFAR-10 Batch 1:  Cost :0.56712, Accuracy on Training 0.8250 -Validation Accuracy: 0.5266
# Epoch 49, CIFAR-10 Batch 1:  Cost :0.60334, Accuracy on Training 0.8000 -Validation Accuracy: 0.5190
# Epoch 50, CIFAR-10 Batch 1:  Cost :0.58393, Accuracy on Training 0.8000 -Validation Accuracy: 0.5322

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost :2.25204, Accuracy on Training 0.1750 -Validation Accuracy: 0.1970
# Epoch  1, CIFAR-10 Batch 2:  Cost :2.05137, Accuracy on Training 0.1500 -Validation Accuracy: 0.2490
# Epoch  1, CIFAR-10 Batch 3:  Cost :1.77771, Accuracy on Training 0.3500 -Validation Accuracy: 0.2490
# Epoch  1, CIFAR-10 Batch 4:  Cost :1.83091, Accuracy on Training 0.2500 -Validation Accuracy: 0.2838
# Epoch  1, CIFAR-10 Batch 5:  Cost :1.77111, Accuracy on Training 0.3750 -Validation Accuracy: 0.2960
# Epoch  2, CIFAR-10 Batch 1:  Cost :2.00555, Accuracy on Training 0.2000 -Validation Accuracy: 0.3004
# Epoch  2, CIFAR-10 Batch 2:  Cost :1.88016, Accuracy on Training 0.1750 -Validation Accuracy: 0.3246
# Epoch  2, CIFAR-10 Batch 3:  Cost :1.66956, Accuracy on Training 0.3500 -Validation Accuracy: 0.3086
# Epoch  2, CIFAR-10 Batch 4:  Cost :1.67320, Accuracy on Training 0.3750 -Validation Accuracy: 0.3198
# Epoch  2, CIFAR-10 Batch 5:  Cost :1.76146, Accuracy on Training 0.4000 -Validation Accuracy: 0.3296
# Epoch  3, CIFAR-10 Batch 1:  Cost :1.92966, Accuracy on Training 0.2250 -Validation Accuracy: 0.3284
# Epoch  3, CIFAR-10 Batch 2:  Cost :1.75332, Accuracy on Training 0.3000 -Validation Accuracy: 0.3542
# Epoch  3, CIFAR-10 Batch 3:  Cost :1.60655, Accuracy on Training 0.3750 -Validation Accuracy: 0.3490
# Epoch  3, CIFAR-10 Batch 4:  Cost :1.58743, Accuracy on Training 0.3750 -Validation Accuracy: 0.3722
# Epoch  3, CIFAR-10 Batch 5:  Cost :1.67746, Accuracy on Training 0.4750 -Validation Accuracy: 0.3522
# Epoch  4, CIFAR-10 Batch 1:  Cost :1.76824, Accuracy on Training 0.2750 -Validation Accuracy: 0.3850
# Epoch  4, CIFAR-10 Batch 2:  Cost :1.74631, Accuracy on Training 0.4000 -Validation Accuracy: 0.3946
# Epoch  4, CIFAR-10 Batch 3:  Cost :1.55395, Accuracy on Training 0.3250 -Validation Accuracy: 0.3928
# Epoch  4, CIFAR-10 Batch 4:  Cost :1.57024, Accuracy on Training 0.3750 -Validation Accuracy: 0.3942
# Epoch  4, CIFAR-10 Batch 5:  Cost :1.62120, Accuracy on Training 0.4500 -Validation Accuracy: 0.3950
# Epoch  5, CIFAR-10 Batch 1:  Cost :1.74085, Accuracy on Training 0.2750 -Validation Accuracy: 0.3734
# Epoch  5, CIFAR-10 Batch 2:  Cost :1.63724, Accuracy on Training 0.4000 -Validation Accuracy: 0.4168
# Epoch  5, CIFAR-10 Batch 3:  Cost :1.50824, Accuracy on Training 0.3500 -Validation Accuracy: 0.4268
# Epoch  5, CIFAR-10 Batch 4:  Cost :1.53906, Accuracy on Training 0.4000 -Validation Accuracy: 0.4282
# Epoch  5, CIFAR-10 Batch 5:  Cost :1.56853, Accuracy on Training 0.5250 -Validation Accuracy: 0.4264
# Epoch  6, CIFAR-10 Batch 1:  Cost :1.57359, Accuracy on Training 0.3750 -Validation Accuracy: 0.4362
# Epoch  6, CIFAR-10 Batch 2:  Cost :1.61576, Accuracy on Training 0.4000 -Validation Accuracy: 0.4518
# Epoch  6, CIFAR-10 Batch 3:  Cost :1.52805, Accuracy on Training 0.3250 -Validation Accuracy: 0.4400
# Epoch  6, CIFAR-10 Batch 4:  Cost :1.55224, Accuracy on Training 0.4500 -Validation Accuracy: 0.4380
# Epoch  6, CIFAR-10 Batch 5:  Cost :1.47352, Accuracy on Training 0.5250 -Validation Accuracy: 0.4574
# Epoch  7, CIFAR-10 Batch 1:  Cost :1.49667, Accuracy on Training 0.4500 -Validation Accuracy: 0.4716
# Epoch  7, CIFAR-10 Batch 2:  Cost :1.50959, Accuracy on Training 0.4500 -Validation Accuracy: 0.4682
# Epoch  7, CIFAR-10 Batch 3:  Cost :1.45475, Accuracy on Training 0.3750 -Validation Accuracy: 0.4626
# Epoch  7, CIFAR-10 Batch 4:  Cost :1.42848, Accuracy on Training 0.4250 -Validation Accuracy: 0.4844
# Epoch  7, CIFAR-10 Batch 5:  Cost :1.48802, Accuracy on Training 0.5500 -Validation Accuracy: 0.4832
# Epoch  8, CIFAR-10 Batch 1:  Cost :1.43601, Accuracy on Training 0.6000 -Validation Accuracy: 0.4824
# Epoch  8, CIFAR-10 Batch 2:  Cost :1.49815, Accuracy on Training 0.5250 -Validation Accuracy: 0.4900
# Epoch  8, CIFAR-10 Batch 3:  Cost :1.34905, Accuracy on Training 0.4000 -Validation Accuracy: 0.4932
# Epoch  8, CIFAR-10 Batch 4:  Cost :1.41484, Accuracy on Training 0.4250 -Validation Accuracy: 0.4978
# Epoch  8, CIFAR-10 Batch 5:  Cost :1.31774, Accuracy on Training 0.6000 -Validation Accuracy: 0.5134
# Epoch  9, CIFAR-10 Batch 1:  Cost :1.36229, Accuracy on Training 0.4750 -Validation Accuracy: 0.4996
# Epoch  9, CIFAR-10 Batch 2:  Cost :1.42265, Accuracy on Training 0.5500 -Validation Accuracy: 0.5132
# Epoch  9, CIFAR-10 Batch 3:  Cost :1.27370, Accuracy on Training 0.4750 -Validation Accuracy: 0.5140
# Epoch  9, CIFAR-10 Batch 4:  Cost :1.32723, Accuracy on Training 0.5250 -Validation Accuracy: 0.5192
# Epoch  9, CIFAR-10 Batch 5:  Cost :1.26171, Accuracy on Training 0.6250 -Validation Accuracy: 0.5218
# Epoch 10, CIFAR-10 Batch 1:  Cost :1.32784, Accuracy on Training 0.5500 -Validation Accuracy: 0.5238
# Epoch 10, CIFAR-10 Batch 2:  Cost :1.25825, Accuracy on Training 0.7000 -Validation Accuracy: 0.5236
# Epoch 10, CIFAR-10 Batch 3:  Cost :1.21650, Accuracy on Training 0.6000 -Validation Accuracy: 0.5272
# Epoch 10, CIFAR-10 Batch 4:  Cost :1.29735, Accuracy on Training 0.4750 -Validation Accuracy: 0.5170
# Epoch 10, CIFAR-10 Batch 5:  Cost :1.15301, Accuracy on Training 0.6000 -Validation Accuracy: 0.5372
# Epoch 11, CIFAR-10 Batch 1:  Cost :1.16387, Accuracy on Training 0.6250 -Validation Accuracy: 0.5430
# Epoch 11, CIFAR-10 Batch 2:  Cost :1.24337, Accuracy on Training 0.6000 -Validation Accuracy: 0.5328
# Epoch 11, CIFAR-10 Batch 3:  Cost :1.13538, Accuracy on Training 0.6000 -Validation Accuracy: 0.5504
# Epoch 11, CIFAR-10 Batch 4:  Cost :1.23061, Accuracy on Training 0.5750 -Validation Accuracy: 0.5302
# Epoch 11, CIFAR-10 Batch 5:  Cost :1.08127, Accuracy on Training 0.7250 -Validation Accuracy: 0.5514
# Epoch 12, CIFAR-10 Batch 1:  Cost :1.16727, Accuracy on Training 0.5750 -Validation Accuracy: 0.5308
# Epoch 12, CIFAR-10 Batch 2:  Cost :1.13327, Accuracy on Training 0.6250 -Validation Accuracy: 0.5398
# Epoch 12, CIFAR-10 Batch 3:  Cost :1.11011, Accuracy on Training 0.6500 -Validation Accuracy: 0.5484
# Epoch 12, CIFAR-10 Batch 4:  Cost :1.23892, Accuracy on Training 0.5500 -Validation Accuracy: 0.5244
# Epoch 12, CIFAR-10 Batch 5:  Cost :1.05220, Accuracy on Training 0.7250 -Validation Accuracy: 0.5638
# Epoch 13, CIFAR-10 Batch 1:  Cost :1.08420, Accuracy on Training 0.6250 -Validation Accuracy: 0.5442
# Epoch 13, CIFAR-10 Batch 2:  Cost :1.11331, Accuracy on Training 0.6750 -Validation Accuracy: 0.5596
# Epoch 13, CIFAR-10 Batch 3:  Cost :1.10617, Accuracy on Training 0.6000 -Validation Accuracy: 0.5532
# Epoch 13, CIFAR-10 Batch 4:  Cost :1.20206, Accuracy on Training 0.5000 -Validation Accuracy: 0.5636
# Epoch 13, CIFAR-10 Batch 5:  Cost :0.99571, Accuracy on Training 0.6500 -Validation Accuracy: 0.5634
# Epoch 14, CIFAR-10 Batch 1:  Cost :1.06217, Accuracy on Training 0.6000 -Validation Accuracy: 0.5366
# Epoch 14, CIFAR-10 Batch 2:  Cost :1.00236, Accuracy on Training 0.6750 -Validation Accuracy: 0.5810
# Epoch 14, CIFAR-10 Batch 3:  Cost :1.12394, Accuracy on Training 0.6250 -Validation Accuracy: 0.5568
# Epoch 14, CIFAR-10 Batch 4:  Cost :1.18930, Accuracy on Training 0.5000 -Validation Accuracy: 0.5594
# Epoch 14, CIFAR-10 Batch 5:  Cost :1.00613, Accuracy on Training 0.6250 -Validation Accuracy: 0.5746
# Epoch 15, CIFAR-10 Batch 1:  Cost :0.99457, Accuracy on Training 0.6000 -Validation Accuracy: 0.5496
# Epoch 15, CIFAR-10 Batch 2:  Cost :1.07563, Accuracy on Training 0.6750 -Validation Accuracy: 0.5520
# Epoch 15, CIFAR-10 Batch 3:  Cost :1.12252, Accuracy on Training 0.6000 -Validation Accuracy: 0.5558
# Epoch 15, CIFAR-10 Batch 4:  Cost :1.15666, Accuracy on Training 0.5750 -Validation Accuracy: 0.5784
# Epoch 15, CIFAR-10 Batch 5:  Cost :0.88052, Accuracy on Training 0.6750 -Validation Accuracy: 0.5830
# Epoch 16, CIFAR-10 Batch 1:  Cost :0.94895, Accuracy on Training 0.7250 -Validation Accuracy: 0.5712
# Epoch 16, CIFAR-10 Batch 2:  Cost :0.96918, Accuracy on Training 0.7250 -Validation Accuracy: 0.5922
# Epoch 16, CIFAR-10 Batch 3:  Cost :0.96721, Accuracy on Training 0.7000 -Validation Accuracy: 0.5682
# Epoch 16, CIFAR-10 Batch 4:  Cost :1.13520, Accuracy on Training 0.5750 -Validation Accuracy: 0.5822
# Epoch 16, CIFAR-10 Batch 5:  Cost :0.90669, Accuracy on Training 0.6250 -Validation Accuracy: 0.5934
# Epoch 17, CIFAR-10 Batch 1:  Cost :0.89484, Accuracy on Training 0.6500 -Validation Accuracy: 0.5864
# Epoch 17, CIFAR-10 Batch 2:  Cost :0.89442, Accuracy on Training 0.7750 -Validation Accuracy: 0.5834
# Epoch 17, CIFAR-10 Batch 3:  Cost :0.98080, Accuracy on Training 0.7000 -Validation Accuracy: 0.5734
# Epoch 17, CIFAR-10 Batch 4:  Cost :1.07421, Accuracy on Training 0.5750 -Validation Accuracy: 0.5922
# Epoch 17, CIFAR-10 Batch 5:  Cost :0.82105, Accuracy on Training 0.6750 -Validation Accuracy: 0.5950
# Epoch 18, CIFAR-10 Batch 1:  Cost :0.87028, Accuracy on Training 0.7250 -Validation Accuracy: 0.6004
# Epoch 18, CIFAR-10 Batch 2:  Cost :0.84437, Accuracy on Training 0.7500 -Validation Accuracy: 0.5926
# Epoch 18, CIFAR-10 Batch 3:  Cost :0.89879, Accuracy on Training 0.6500 -Validation Accuracy: 0.5854
# Epoch 18, CIFAR-10 Batch 4:  Cost :1.10197, Accuracy on Training 0.5750 -Validation Accuracy: 0.5750
# Epoch 18, CIFAR-10 Batch 5:  Cost :0.87332, Accuracy on Training 0.6500 -Validation Accuracy: 0.5970
# Epoch 19, CIFAR-10 Batch 1:  Cost :0.81968, Accuracy on Training 0.7750 -Validation Accuracy: 0.5962
# Epoch 19, CIFAR-10 Batch 2:  Cost :0.79076, Accuracy on Training 0.7500 -Validation Accuracy: 0.6062
# Epoch 19, CIFAR-10 Batch 3:  Cost :0.81072, Accuracy on Training 0.7250 -Validation Accuracy: 0.6000
# Epoch 19, CIFAR-10 Batch 4:  Cost :1.08701, Accuracy on Training 0.5250 -Validation Accuracy: 0.6012
# Epoch 19, CIFAR-10 Batch 5:  Cost :0.79347, Accuracy on Training 0.7250 -Validation Accuracy: 0.6164
# Epoch 20, CIFAR-10 Batch 1:  Cost :0.79389, Accuracy on Training 0.7750 -Validation Accuracy: 0.6182
# Epoch 20, CIFAR-10 Batch 2:  Cost :0.74194, Accuracy on Training 0.8000 -Validation Accuracy: 0.6124
# Epoch 20, CIFAR-10 Batch 3:  Cost :0.83399, Accuracy on Training 0.7250 -Validation Accuracy: 0.6022
# Epoch 20, CIFAR-10 Batch 4:  Cost :1.07221, Accuracy on Training 0.5750 -Validation Accuracy: 0.6126
# Epoch 20, CIFAR-10 Batch 5:  Cost :0.79293, Accuracy on Training 0.7500 -Validation Accuracy: 0.6182
# Epoch 21, CIFAR-10 Batch 1:  Cost :0.92475, Accuracy on Training 0.7000 -Validation Accuracy: 0.5828
# Epoch 21, CIFAR-10 Batch 2:  Cost :0.74972, Accuracy on Training 0.9000 -Validation Accuracy: 0.6172
# Epoch 21, CIFAR-10 Batch 3:  Cost :0.82299, Accuracy on Training 0.7000 -Validation Accuracy: 0.6160
# Epoch 21, CIFAR-10 Batch 4:  Cost :1.06801, Accuracy on Training 0.5750 -Validation Accuracy: 0.6106
# Epoch 21, CIFAR-10 Batch 5:  Cost :0.75531, Accuracy on Training 0.7750 -Validation Accuracy: 0.6332
# Epoch 22, CIFAR-10 Batch 1:  Cost :0.84319, Accuracy on Training 0.7500 -Validation Accuracy: 0.6076
# Epoch 22, CIFAR-10 Batch 2:  Cost :0.71609, Accuracy on Training 0.7500 -Validation Accuracy: 0.6120
# Epoch 22, CIFAR-10 Batch 3:  Cost :0.79641, Accuracy on Training 0.7500 -Validation Accuracy: 0.5868
# Epoch 22, CIFAR-10 Batch 4:  Cost :0.97482, Accuracy on Training 0.6250 -Validation Accuracy: 0.6178
# Epoch 22, CIFAR-10 Batch 5:  Cost :0.75367, Accuracy on Training 0.7500 -Validation Accuracy: 0.6226
# Epoch 23, CIFAR-10 Batch 1:  Cost :0.77398, Accuracy on Training 0.8000 -Validation Accuracy: 0.6138
# Epoch 23, CIFAR-10 Batch 2:  Cost :0.69735, Accuracy on Training 0.8000 -Validation Accuracy: 0.6292
# Epoch 23, CIFAR-10 Batch 3:  Cost :0.76036, Accuracy on Training 0.7250 -Validation Accuracy: 0.6266
# Epoch 23, CIFAR-10 Batch 4:  Cost :1.03874, Accuracy on Training 0.6500 -Validation Accuracy: 0.6230
# Epoch 23, CIFAR-10 Batch 5:  Cost :0.66116, Accuracy on Training 0.8500 -Validation Accuracy: 0.6368
# Epoch 24, CIFAR-10 Batch 1:  Cost :0.77392, Accuracy on Training 0.7250 -Validation Accuracy: 0.6304
# Epoch 24, CIFAR-10 Batch 2:  Cost :0.62356, Accuracy on Training 0.8250 -Validation Accuracy: 0.6358
# Epoch 24, CIFAR-10 Batch 3:  Cost :0.69200, Accuracy on Training 0.7750 -Validation Accuracy: 0.6254
# Epoch 24, CIFAR-10 Batch 4:  Cost :1.01803, Accuracy on Training 0.6250 -Validation Accuracy: 0.6266
# Epoch 24, CIFAR-10 Batch 5:  Cost :0.67251, Accuracy on Training 0.8500 -Validation Accuracy: 0.6336
# Epoch 25, CIFAR-10 Batch 1:  Cost :0.73836, Accuracy on Training 0.7500 -Validation Accuracy: 0.6308
# Epoch 25, CIFAR-10 Batch 2:  Cost :0.64401, Accuracy on Training 0.8000 -Validation Accuracy: 0.6248
# Epoch 25, CIFAR-10 Batch 3:  Cost :0.74169, Accuracy on Training 0.7250 -Validation Accuracy: 0.6282
# Epoch 25, CIFAR-10 Batch 4:  Cost :0.95299, Accuracy on Training 0.6500 -Validation Accuracy: 0.6328
# Epoch 25, CIFAR-10 Batch 5:  Cost :0.69224, Accuracy on Training 0.8500 -Validation Accuracy: 0.6326
# Epoch 26, CIFAR-10 Batch 1:  Cost :0.73832, Accuracy on Training 0.7500 -Validation Accuracy: 0.6380
# Epoch 26, CIFAR-10 Batch 2:  Cost :0.60402, Accuracy on Training 0.8750 -Validation Accuracy: 0.6338
# Epoch 26, CIFAR-10 Batch 3:  Cost :0.75298, Accuracy on Training 0.7250 -Validation Accuracy: 0.6334
# Epoch 26, CIFAR-10 Batch 4:  Cost :0.91752, Accuracy on Training 0.6750 -Validation Accuracy: 0.6384
# Epoch 26, CIFAR-10 Batch 5:  Cost :0.65812, Accuracy on Training 0.8750 -Validation Accuracy: 0.6420
# Epoch 27, CIFAR-10 Batch 1:  Cost :0.66516, Accuracy on Training 0.8250 -Validation Accuracy: 0.6340
# Epoch 27, CIFAR-10 Batch 2:  Cost :0.60165, Accuracy on Training 0.8500 -Validation Accuracy: 0.6268
# Epoch 27, CIFAR-10 Batch 3:  Cost :0.72696, Accuracy on Training 0.7250 -Validation Accuracy: 0.6354
# Epoch 27, CIFAR-10 Batch 4:  Cost :0.92842, Accuracy on Training 0.6500 -Validation Accuracy: 0.6466
# Epoch 27, CIFAR-10 Batch 5:  Cost :0.61276, Accuracy on Training 0.8250 -Validation Accuracy: 0.6454
# Epoch 28, CIFAR-10 Batch 1:  Cost :0.70812, Accuracy on Training 0.8250 -Validation Accuracy: 0.6372
# Epoch 28, CIFAR-10 Batch 2:  Cost :0.56296, Accuracy on Training 0.8750 -Validation Accuracy: 0.6488
# Epoch 28, CIFAR-10 Batch 3:  Cost :0.84356, Accuracy on Training 0.6750 -Validation Accuracy: 0.5898
# Epoch 28, CIFAR-10 Batch 4:  Cost :0.92801, Accuracy on Training 0.6500 -Validation Accuracy: 0.6454
# Epoch 28, CIFAR-10 Batch 5:  Cost :0.61698, Accuracy on Training 0.7750 -Validation Accuracy: 0.6420
# Epoch 29, CIFAR-10 Batch 1:  Cost :0.63506, Accuracy on Training 0.8250 -Validation Accuracy: 0.6548
# Epoch 29, CIFAR-10 Batch 2:  Cost :0.60634, Accuracy on Training 0.8750 -Validation Accuracy: 0.6366
# Epoch 29, CIFAR-10 Batch 3:  Cost :0.68452, Accuracy on Training 0.8000 -Validation Accuracy: 0.6252
# Epoch 29, CIFAR-10 Batch 4:  Cost :0.90889, Accuracy on Training 0.6000 -Validation Accuracy: 0.6406
# Epoch 29, CIFAR-10 Batch 5:  Cost :0.61411, Accuracy on Training 0.9250 -Validation Accuracy: 0.6520
# Epoch 30, CIFAR-10 Batch 1:  Cost :0.66374, Accuracy on Training 0.8000 -Validation Accuracy: 0.6452
# Epoch 30, CIFAR-10 Batch 2:  Cost :0.60709, Accuracy on Training 0.8500 -Validation Accuracy: 0.6552
# Epoch 30, CIFAR-10 Batch 3:  Cost :0.67487, Accuracy on Training 0.7750 -Validation Accuracy: 0.6334
# Epoch 30, CIFAR-10 Batch 4:  Cost :0.85274, Accuracy on Training 0.7000 -Validation Accuracy: 0.6570
# Epoch 30, CIFAR-10 Batch 5:  Cost :0.57022, Accuracy on Training 0.8500 -Validation Accuracy: 0.6444
# Epoch 31, CIFAR-10 Batch 1:  Cost :0.66368, Accuracy on Training 0.7750 -Validation Accuracy: 0.6554
# Epoch 31, CIFAR-10 Batch 2:  Cost :0.54551, Accuracy on Training 0.8750 -Validation Accuracy: 0.6540
# Epoch 31, CIFAR-10 Batch 3:  Cost :0.63679, Accuracy on Training 0.7750 -Validation Accuracy: 0.6504
# Epoch 31, CIFAR-10 Batch 4:  Cost :0.76686, Accuracy on Training 0.7250 -Validation Accuracy: 0.6510
# Epoch 31, CIFAR-10 Batch 5:  Cost :0.57331, Accuracy on Training 0.8750 -Validation Accuracy: 0.6514
# Epoch 32, CIFAR-10 Batch 1:  Cost :0.72168, Accuracy on Training 0.7500 -Validation Accuracy: 0.6470
# Epoch 32, CIFAR-10 Batch 2:  Cost :0.56185, Accuracy on Training 0.9250 -Validation Accuracy: 0.6476
# Epoch 32, CIFAR-10 Batch 3:  Cost :0.60370, Accuracy on Training 0.7750 -Validation Accuracy: 0.6544
# Epoch 32, CIFAR-10 Batch 4:  Cost :0.93395, Accuracy on Training 0.6500 -Validation Accuracy: 0.6546
# Epoch 32, CIFAR-10 Batch 5:  Cost :0.58612, Accuracy on Training 0.8250 -Validation Accuracy: 0.6540
# Epoch 33, CIFAR-10 Batch 1:  Cost :0.66172, Accuracy on Training 0.8250 -Validation Accuracy: 0.6522
# Epoch 33, CIFAR-10 Batch 2:  Cost :0.56682, Accuracy on Training 0.8500 -Validation Accuracy: 0.6600
# Epoch 33, CIFAR-10 Batch 3:  Cost :0.56716, Accuracy on Training 0.7750 -Validation Accuracy: 0.6386
# Epoch 33, CIFAR-10 Batch 4:  Cost :0.83028, Accuracy on Training 0.7500 -Validation Accuracy: 0.6562
# Epoch 33, CIFAR-10 Batch 5:  Cost :0.53417, Accuracy on Training 0.9000 -Validation Accuracy: 0.6538
# Epoch 34, CIFAR-10 Batch 1:  Cost :0.62847, Accuracy on Training 0.8500 -Validation Accuracy: 0.6588
# Epoch 34, CIFAR-10 Batch 2:  Cost :0.49509, Accuracy on Training 0.9000 -Validation Accuracy: 0.6590
# Epoch 34, CIFAR-10 Batch 3:  Cost :0.57651, Accuracy on Training 0.8000 -Validation Accuracy: 0.6460
# Epoch 34, CIFAR-10 Batch 4:  Cost :0.80798, Accuracy on Training 0.7500 -Validation Accuracy: 0.6580
# Epoch 34, CIFAR-10 Batch 5:  Cost :0.53120, Accuracy on Training 0.9500 -Validation Accuracy: 0.6592
# Epoch 35, CIFAR-10 Batch 1:  Cost :0.78734, Accuracy on Training 0.7500 -Validation Accuracy: 0.6452
# Epoch 35, CIFAR-10 Batch 2:  Cost :0.53639, Accuracy on Training 0.9000 -Validation Accuracy: 0.6502
# Epoch 35, CIFAR-10 Batch 3:  Cost :0.54048, Accuracy on Training 0.8500 -Validation Accuracy: 0.6610
# Epoch 35, CIFAR-10 Batch 4:  Cost :0.79420, Accuracy on Training 0.8000 -Validation Accuracy: 0.6542
# Epoch 35, CIFAR-10 Batch 5:  Cost :0.53570, Accuracy on Training 0.9500 -Validation Accuracy: 0.6592
# Epoch 36, CIFAR-10 Batch 1:  Cost :0.63128, Accuracy on Training 0.8250 -Validation Accuracy: 0.6714
# Epoch 36, CIFAR-10 Batch 2:  Cost :0.51529, Accuracy on Training 0.8750 -Validation Accuracy: 0.6584
# Epoch 36, CIFAR-10 Batch 3:  Cost :0.56488, Accuracy on Training 0.8500 -Validation Accuracy: 0.6552
# Epoch 36, CIFAR-10 Batch 4:  Cost :0.77602, Accuracy on Training 0.8250 -Validation Accuracy: 0.6594
# Epoch 36, CIFAR-10 Batch 5:  Cost :0.51391, Accuracy on Training 0.9500 -Validation Accuracy: 0.6582
# Epoch 37, CIFAR-10 Batch 1:  Cost :0.62197, Accuracy on Training 0.8250 -Validation Accuracy: 0.6658
# Epoch 37, CIFAR-10 Batch 2:  Cost :0.54664, Accuracy on Training 0.8750 -Validation Accuracy: 0.6532
# Epoch 37, CIFAR-10 Batch 3:  Cost :0.55433, Accuracy on Training 0.8500 -Validation Accuracy: 0.6540
# Epoch 37, CIFAR-10 Batch 4:  Cost :0.80896, Accuracy on Training 0.7500 -Validation Accuracy: 0.6666
# Epoch 37, CIFAR-10 Batch 5:  Cost :0.52391, Accuracy on Training 0.9000 -Validation Accuracy: 0.6680
# Epoch 38, CIFAR-10 Batch 1:  Cost :0.63484, Accuracy on Training 0.8250 -Validation Accuracy: 0.6544
# Epoch 38, CIFAR-10 Batch 2:  Cost :0.49302, Accuracy on Training 0.9000 -Validation Accuracy: 0.6572
# Epoch 38, CIFAR-10 Batch 3:  Cost :0.53742, Accuracy on Training 0.8250 -Validation Accuracy: 0.6540
# Epoch 38, CIFAR-10 Batch 4:  Cost :0.73322, Accuracy on Training 0.7750 -Validation Accuracy: 0.6592
# Epoch 38, CIFAR-10 Batch 5:  Cost :0.49349, Accuracy on Training 0.9250 -Validation Accuracy: 0.6626
# Epoch 39, CIFAR-10 Batch 1:  Cost :0.68337, Accuracy on Training 0.8000 -Validation Accuracy: 0.6652
# Epoch 39, CIFAR-10 Batch 2:  Cost :0.61847, Accuracy on Training 0.8000 -Validation Accuracy: 0.6604
# Epoch 39, CIFAR-10 Batch 3:  Cost :0.53052, Accuracy on Training 0.8000 -Validation Accuracy: 0.6544
# Epoch 39, CIFAR-10 Batch 4:  Cost :0.65177, Accuracy on Training 0.8500 -Validation Accuracy: 0.6634
# Epoch 39, CIFAR-10 Batch 5:  Cost :0.44665, Accuracy on Training 0.9000 -Validation Accuracy: 0.6712
# Epoch 40, CIFAR-10 Batch 1:  Cost :0.61611, Accuracy on Training 0.8500 -Validation Accuracy: 0.6624
# Epoch 40, CIFAR-10 Batch 2:  Cost :0.45703, Accuracy on Training 0.9250 -Validation Accuracy: 0.6556
# Epoch 40, CIFAR-10 Batch 3:  Cost :0.51734, Accuracy on Training 0.8500 -Validation Accuracy: 0.6660
# Epoch 40, CIFAR-10 Batch 4:  Cost :0.61421, Accuracy on Training 0.8750 -Validation Accuracy: 0.6714
# Epoch 40, CIFAR-10 Batch 5:  Cost :0.46772, Accuracy on Training 0.9250 -Validation Accuracy: 0.6686
# Epoch 41, CIFAR-10 Batch 1:  Cost :0.60699, Accuracy on Training 0.8250 -Validation Accuracy: 0.6632
# Epoch 41, CIFAR-10 Batch 2:  Cost :0.47791, Accuracy on Training 0.9000 -Validation Accuracy: 0.6678
# Epoch 41, CIFAR-10 Batch 3:  Cost :0.49620, Accuracy on Training 0.8500 -Validation Accuracy: 0.6614
# Epoch 41, CIFAR-10 Batch 4:  Cost :0.72591, Accuracy on Training 0.8250 -Validation Accuracy: 0.6694
# Epoch 41, CIFAR-10 Batch 5:  Cost :0.49258, Accuracy on Training 0.8750 -Validation Accuracy: 0.6726
# Epoch 42, CIFAR-10 Batch 1:  Cost :0.57924, Accuracy on Training 0.8500 -Validation Accuracy: 0.6662
# Epoch 42, CIFAR-10 Batch 2:  Cost :0.43612, Accuracy on Training 0.9000 -Validation Accuracy: 0.6606
# Epoch 42, CIFAR-10 Batch 3:  Cost :0.50871, Accuracy on Training 0.8500 -Validation Accuracy: 0.6620
# Epoch 42, CIFAR-10 Batch 4:  Cost :0.75848, Accuracy on Training 0.7500 -Validation Accuracy: 0.6590
# Epoch 42, CIFAR-10 Batch 5:  Cost :0.46374, Accuracy on Training 0.9500 -Validation Accuracy: 0.6628
# Epoch 43, CIFAR-10 Batch 1:  Cost :0.55973, Accuracy on Training 0.8500 -Validation Accuracy: 0.6666
# Epoch 43, CIFAR-10 Batch 2:  Cost :0.48528, Accuracy on Training 0.9000 -Validation Accuracy: 0.6676
# Epoch 43, CIFAR-10 Batch 3:  Cost :0.48059, Accuracy on Training 0.8500 -Validation Accuracy: 0.6728
# Epoch 43, CIFAR-10 Batch 4:  Cost :0.66670, Accuracy on Training 0.7750 -Validation Accuracy: 0.6774
# Epoch 43, CIFAR-10 Batch 5:  Cost :0.48143, Accuracy on Training 0.8500 -Validation Accuracy: 0.6654
# Epoch 44, CIFAR-10 Batch 1:  Cost :0.58891, Accuracy on Training 0.8500 -Validation Accuracy: 0.6652
# Epoch 44, CIFAR-10 Batch 2:  Cost :0.45798, Accuracy on Training 0.9000 -Validation Accuracy: 0.6678
# Epoch 44, CIFAR-10 Batch 3:  Cost :0.45377, Accuracy on Training 0.8250 -Validation Accuracy: 0.6600
# Epoch 44, CIFAR-10 Batch 4:  Cost :0.73278, Accuracy on Training 0.7750 -Validation Accuracy: 0.6674
# Epoch 44, CIFAR-10 Batch 5:  Cost :0.42773, Accuracy on Training 0.9250 -Validation Accuracy: 0.6686
# Epoch 45, CIFAR-10 Batch 1:  Cost :0.59714, Accuracy on Training 0.8500 -Validation Accuracy: 0.6646
# Epoch 45, CIFAR-10 Batch 2:  Cost :0.48279, Accuracy on Training 0.9000 -Validation Accuracy: 0.6662
# Epoch 45, CIFAR-10 Batch 3:  Cost :0.52752, Accuracy on Training 0.8500 -Validation Accuracy: 0.6536
# Epoch 45, CIFAR-10 Batch 4:  Cost :0.69423, Accuracy on Training 0.8000 -Validation Accuracy: 0.6648
# Epoch 45, CIFAR-10 Batch 5:  Cost :0.43885, Accuracy on Training 0.9500 -Validation Accuracy: 0.6710
# Epoch 46, CIFAR-10 Batch 1:  Cost :0.53698, Accuracy on Training 0.8500 -Validation Accuracy: 0.6724
# Epoch 46, CIFAR-10 Batch 2:  Cost :0.48403, Accuracy on Training 0.8500 -Validation Accuracy: 0.6620
# Epoch 46, CIFAR-10 Batch 3:  Cost :0.48510, Accuracy on Training 0.8250 -Validation Accuracy: 0.6582
# Epoch 46, CIFAR-10 Batch 4:  Cost :0.68337, Accuracy on Training 0.8750 -Validation Accuracy: 0.6736
# Epoch 46, CIFAR-10 Batch 5:  Cost :0.44050, Accuracy on Training 0.9250 -Validation Accuracy: 0.6698
# Epoch 47, CIFAR-10 Batch 1:  Cost :0.56421, Accuracy on Training 0.8250 -Validation Accuracy: 0.6638
# Epoch 47, CIFAR-10 Batch 2:  Cost :0.53046, Accuracy on Training 0.8500 -Validation Accuracy: 0.6456
# Epoch 47, CIFAR-10 Batch 3:  Cost :0.44569, Accuracy on Training 0.8500 -Validation Accuracy: 0.6692
# Epoch 47, CIFAR-10 Batch 4:  Cost :0.69238, Accuracy on Training 0.7500 -Validation Accuracy: 0.6624
# Epoch 47, CIFAR-10 Batch 5:  Cost :0.41297, Accuracy on Training 0.9750 -Validation Accuracy: 0.6736
# Epoch 48, CIFAR-10 Batch 1:  Cost :0.56146, Accuracy on Training 0.8750 -Validation Accuracy: 0.6744
# Epoch 48, CIFAR-10 Batch 2:  Cost :0.43826, Accuracy on Training 0.9000 -Validation Accuracy: 0.6680
# Epoch 48, CIFAR-10 Batch 3:  Cost :0.47520, Accuracy on Training 0.8250 -Validation Accuracy: 0.6670
# Epoch 48, CIFAR-10 Batch 4:  Cost :0.69124, Accuracy on Training 0.8750 -Validation Accuracy: 0.6744
# Epoch 48, CIFAR-10 Batch 5:  Cost :0.36909, Accuracy on Training 0.9750 -Validation Accuracy: 0.6774
# Epoch 49, CIFAR-10 Batch 1:  Cost :0.54126, Accuracy on Training 0.8750 -Validation Accuracy: 0.6726
# Epoch 49, CIFAR-10 Batch 2:  Cost :0.53370, Accuracy on Training 0.8500 -Validation Accuracy: 0.6686
# Epoch 49, CIFAR-10 Batch 3:  Cost :0.48533, Accuracy on Training 0.9000 -Validation Accuracy: 0.6704
# Epoch 49, CIFAR-10 Batch 4:  Cost :0.67548, Accuracy on Training 0.8500 -Validation Accuracy: 0.6716
# Epoch 49, CIFAR-10 Batch 5:  Cost :0.39491, Accuracy on Training 0.9750 -Validation Accuracy: 0.6732
# Epoch 50, CIFAR-10 Batch 1:  Cost :0.54006, Accuracy on Training 0.8750 -Validation Accuracy: 0.6844
# Epoch 50, CIFAR-10 Batch 2:  Cost :0.45323, Accuracy on Training 0.9000 -Validation Accuracy: 0.6756
# Epoch 50, CIFAR-10 Batch 3:  Cost :0.47646, Accuracy on Training 0.8250 -Validation Accuracy: 0.6682
# Epoch 50, CIFAR-10 Batch 4:  Cost :0.67257, Accuracy on Training 0.8750 -Validation Accuracy: 0.6752
# Epoch 50, CIFAR-10 Batch 5:  Cost :0.38940, Accuracy on Training 0.9250 -Validation Accuracy: 0.6796

# %% [markdown]
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        display_image_predictions(random_test_features, random_test_labels, random_test_predictions )


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6705893987341772
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # By applying simple CNN model on a CIFAR-10 dataset we are able to achive accuracy of more than 60% which is quite good.
